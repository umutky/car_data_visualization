# %% [markdown]
# # Data Visualization

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
#Import data:
car = pd.read_csv(r"C:\Users\umutk\OneDrive\Masaüstü\Genel\Data_Science\car_details.csv")
print(car.head())
print(car.tail())
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner
#                                      name  year  selling_price  km_driven  \
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# ...

# %%
#Data type control:
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %%
#NULL value control:
car.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
#Selecting categorical data:
categorical_car = car.select_dtypes(include = ["category","object"])
print(categorical_car)
# Out:
#                                      name    fuel seller_type transmission  \
# 0                           Maruti 800 AC  Petrol  Individual       Manual
# 1                Maruti Wagon R LXI Minor  Petrol  Individual       Manual
# 2                    Hyundai Verna 1.6 SX  Diesel  Individual       Manual
# 3                  Datsun RediGO T Option  Petrol  Individual       Manual
# 4                   Honda Amaze VX i-DTEC  Diesel  Individual       Manual
# ...                                   ...     ...         ...          ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  Diesel  Individual       Manual
# 4336           Hyundai i20 Magna 1.4 CRDi  Diesel  Individual       Manual
# 4337                  Maruti 800 AC BSIII  Petrol  Individual       Manual
# 4338     Hyundai Creta 1.6 CRDi SX Option  Diesel  Individual       Manual
# 4339                     Renault KWID RXT  Petrol  Individual       Manual
#
#              owner
# 0      First Owner
# 1      First Owner
# ...

# %%
# Unique values:
print(car['name'].unique())
print(car['fuel'].unique())
print(car['seller_type'].unique())
print(car['transmission'].unique())
print(car['owner'].unique())
# Out:
# ['Maruti 800 AC' 'Maruti Wagon R LXI Minor' 'Hyundai Verna 1.6 SX' ...
#  'Mahindra Verito 1.5 D6 BSIII'
#  'Toyota Innova 2.5 VX (Diesel) 8 Seater BS IV'
#  'Hyundai i20 Magna 1.4 CRDi']
# ['Petrol' 'Diesel' 'CNG' 'LPG' 'Electric']
# ['Individual' 'Dealer' 'Trustmark Dealer']
# ['Manual' 'Automatic']
# ['First Owner' 'Second Owner' 'Fourth & Above Owner' 'Third Owner'
#  'Test Drive Car']

# %%
car.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner'],
#       dtype='object')

# %%
# Frequency of categorical variable:
categorical_car.value_counts()
# Out:
# name                             fuel    seller_type  transmission  owner
# Maruti Alto 800 LXI              Petrol  Individual   Manual        First Owner     32
# Maruti Swift Dzire VDI           Diesel  Individual   Manual        First Owner     31
# Maruti Alto LXi                  Petrol  Individual   Manual        Second Owner    20
#                                                                     First Owner     20
# Hyundai EON Magna Plus           Petrol  Individual   Manual        First Owner     19
#                                                                                     ..
# Jaguar XJ 5.0 L V8 Supercharged  Petrol  Individual   Automatic     Second Owner     1
# Jaguar XF 2.2 Litre Luxury       Diesel  Dealer       Automatic     First Owner      1
# Isuzu D-Max V-Cross Standard     Diesel  Individual   Manual        First Owner      1
# Hyundai i20 Sportz Option 1.2    Petrol  Individual   Manual        First Owner      1
# ...

# %%
df = car.copy()
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
df_categorical = df.select_dtypes(exclude = ["float","int"])
df_categorical.head()
# Out:
#                        name    fuel seller_type transmission         owner
# 0             Maruti 800 AC  Petrol  Individual       Manual   First Owner
# 1  Maruti Wagon R LXI Minor  Petrol  Individual       Manual   First Owner
# 2      Hyundai Verna 1.6 SX  Diesel  Individual       Manual   First Owner
# 3    Datsun RediGO T Option  Petrol  Individual       Manual   First Owner
# 4     Honda Amaze VX i-DTEC  Diesel  Individual       Manual  Second Owner

# %%
df_categorical.describe().T
# Out:
#              count unique                     top  freq
# name          4340   1491  Maruti Swift Dzire VDI    69
# fuel          4340      5                  Diesel  2153
# seller_type   4340      3              Individual  3244
# transmission  4340      2                  Manual  3892
# owner         4340      5             First Owner  2832

# %%
df["fuel"].value_counts().plot.bar();

# %%
df["seller_type"].value_counts().plot.bar(color = ["blue","purple","pink"], edgecolor = "black");

# %%
df["transmission"].value_counts().plot.bar(color = ["blue","purple"], edgecolor = "black");

# %%
import matplotlib.pyplot as plt
df["owner"].value_counts().plot.bar(color = ["purple","pink","darkblue","lightblue","green"], edgecolor = "black");
plt.title("Bar plot of owner");

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %%
sns.catplot(x = 'owner',y = 'selling_price', data = df);

# %%
sns.catplot(data = df ,x = "fuel",y = "selling_price");

# %%
#Multi-argument Bar Plot:
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.barplot(x = 'owner', y = 'selling_price',hue = 'fuel', data = df);

# %%
# Histogram:
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.displot(df.selling_price);

# %%
sns.histplot(data = df, x = "selling_price");

# %%
sns.histplot(data = df, x = "selling_price", kde = True);

# %%
sns.histplot(data = df, x = "selling_price",bins = 50);

# %%
sns.histplot(data = df, x = "selling_price",bins = 50, kde = True);

# %%
#histogram of km_driven:
df.select_dtypes(include = ["float","int"]).head()
# Out:
#    year  selling_price  km_driven
# 0  2007          60000      70000
# 1  2007         135000      50000
# 2  2012         600000     100000
# 3  2017         250000      46000
# 4  2014         450000     141000

# %%
sns.histplot(data = df, x = "km_driven", bins = 50, kde = True);

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
sns.histplot(data = df, x = "selling_price", bins = 50, hue = "owner");

# %%
df.year.describe().T

# %%
# km_driven and "year" comparison:
#We cut our "year" data.
cut_year = pd.cut(df.year, bins =[1990,2000,2010,2020] )
cut_year.value_counts()
# Out:
# (2010, 2020]    3292
# (2000, 2010]    1007
# (1990, 2000]      41
# Name: year, dtype: int64

# %%
df_new = df.copy()
df_new["cut_year"] = cut_year
df_new.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner      cut_year
# 0  Individual       Manual   First Owner  (2000, 2010]
# 1  Individual       Manual   First Owner  (2000, 2010]
# 2  Individual       Manual   First Owner  (2010, 2020]
# 3  Individual       Manual   First Owner  (2010, 2020]
# 4  Individual       Manual  Second Owner  (2010, 2020]

# %%
sns.histplot(data = df_new, x = "km_driven", bins = 50, hue = "cut_year");

# %%
sns.histplot(data = df_new, x = "selling_price", bins = 50, hue = "cut_year");

# %%
# Density Curve
sns.kdeplot(data = df, x = "selling_price", fill = True);

# %%
(sns
 .FacetGrid(df,
           hue ='fuel',
           height = 8,
           xlim = (0,1000000))
 .map(sns.kdeplot,'selling_price',fill = True)
 .add_legend()
);
# Out:
# C:\Users\umutk\anaconda3\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\umutk\anaconda3\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\umutk\anaconda3\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\umutk\anaconda3\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# ...

# %%
(sns
 .FacetGrid(df,
           hue ='owner',
           height = 8,
           xlim = (0,1000000))
 .map(sns.kdeplot,'selling_price',fill = True)
 .add_legend()
);
# Out:
# C:\Users\umutk\anaconda3\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\umutk\anaconda3\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\umutk\anaconda3\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# C:\Users\umutk\anaconda3\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# ...

# %%
# boxplot
sns.boxplot(data = df, x = "selling_price");

# %%
sns.boxplot(data = df, x = "selling_price", y = "owner");

# %%
sns.boxplot(data = df, x = "selling_price",y = "fuel");

# %%
sns.boxplot(data = df, x = "selling_price",y = "transmission", hue = "fuel");

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
#Scatterplot
sns.scatterplot(data = df, x = "km_driven", y = "selling_price", hue = "year");

# %%
# linear relationship
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.lmplot(data = iris, x = "sepal_length", y = "petal_length", hue = "petal_width");

# %%
sns.lineplot(data = df, x = 'year', y = 'selling_price', hue = "transmission", markers = True);
